# %% [raw]
# ---
# description: FastHTML interface for browsing scans and requesting deliverables.
# output-file: web.html
# title: ptsrv.web
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
