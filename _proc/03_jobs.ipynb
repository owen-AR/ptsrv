# %% [raw]
# ---
# description: Background scan-preparation jobs and render coordination.
# output-file: jobs.html
# title: ptsrv.jobs
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
